# %%
from ipyleaflet import Map, DrawControl, basemaps, basemap_to_tiles, LayersControl, TileLayer
from ipywidgets import Dropdown, VBox, HBox, Output
import json

# 1. Dropdowns iniciales
idioma = Dropdown(
    options=[('Español', 'es'), ('English', 'en')],
    description='Idioma:',
    layout={'width': '200px'}
)

tipo = Dropdown(
    description='Uso:',
    layout={'width': '350px'}
)

# 2. Diccionario de categorías por idioma
categorias = {
    'es': ['Casa', 'Parque', 'Fraccionamiento', 'Rascacielos', 'Edificio histórico',
           'Jardín', 'Tienda', 'Supermercado', 'Canal', 'Río', 'Palacio', 'Ayuntamiento'],
    'en': ['House', 'Park', 'Residential Complex', 'Skyscraper', 'Historical Building',
           'Garden', 'Store', 'Supermarket', 'Canal', 'River', 'Palace', 'City Hall']
}

# 3. Función para actualizar categorías según idioma
def actualizar_categorias(change):
    tipo.options = categorias[idioma.value]
    tipo.value = tipo.options[0]

idioma.observe(actualizar_categorias, names='value')
actualizar_categorias(None)

# 4. Capas base incluyendo personalizadas
capas_base = {
    "OpenStreetMap": basemap_to_tiles(basemaps.OpenStreetMap.Mapnik),
    "Satélite (Esri)": basemap_to_tiles(basemaps.Esri.WorldImagery),
    "Topográfico (Esri)": basemap_to_tiles(basemaps.Esri.WorldTopoMap),
    "Carto Positivo": basemap_to_tiles(basemaps.CartoDB.Positron),
    "Carto Oscuro": basemap_to_tiles(basemaps.CartoDB.DarkMatter),
    "Topográfico (OSM)": TileLayer(
        url="https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png",
        attribution="© OpenTopoMap contributors"
    ),
    "Transporte": TileLayer(
        url="https://tile.memomaps.de/tilegen/{z}/{x}/{y}.png",
        attribution="© MemoMap & Public Transport Tiles"
    )
}

# 5. Dropdown para selector de capas base
selector_capa = Dropdown(
    options=list(capas_base.keys()),
    value="OpenStreetMap",
    description="Mapa:"
)

# 6. Crear el mapa
m = Map(center=(0, 0), zoom=2, min_zoom=1, max_zoom=22)
capa_base_actual = capas_base[selector_capa.value]
m.add_layer(capa_base_actual)

# 7. Actualizar capa base cuando cambia
def actualizar_capa(change):
    global capa_base_actual
    nueva_capa = capas_base[change.new]
    m.substitute_layer(capa_base_actual, nueva_capa)
    capa_base_actual = nueva_capa

selector_capa.observe(actualizar_capa, names='value')
m.add_control(LayersControl(position='topright'))

# 8. Control de dibujo
draw_control = DrawControl()
m.add_control(draw_control)

# 9. Output y guardado
salida = Output()

@draw_control.on_draw
def guardar_clasificado(target, action, geo_json):
    geo_json['properties'] = {
        'uso': tipo.value,
        'idioma': idioma.value
    }
    with open("clasificado.geojson", "a") as f:
        json.dump(geo_json, f)
        f.write("\n")
    with salida:
        print(f"✅ Guardado: {tipo.value} ({idioma.label})")

# 10. Mostrar interfaz
VBox([
    HBox([idioma, tipo, selector_capa]),
    m,
    salida
])
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Idioma:', layout=Layout(width='200px'), options=(('Español…

# %%
# %pip install ipyleaflet
# Out:
# Requirement already satisfied: ipyleaflet in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (0.19.2)
# Requirement already satisfied: branca>=0.5.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipyleaflet) (0.8.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipyleaflet) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipyleaflet) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipyleaflet) (2025.4.0)
# Requirement already satisfied: jinja2>=3 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.15)
# Requirement already satisfied: colorama in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.6)
# Requirement already satisfied: decorator in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\emmanuel\downloads\python - project life\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
